# %% [markdown]
# ### Imports

# %%
import redis
import re
import json
import pandas as pd
import numpy as np
import sys
sys.path.append('../library/')
from core import extractBetween, extractElementsInOrder, exceptionOutput
from datetime import datetime
import nest_asyncio
import asyncio
import arrow
from tqdm import tqdm

r = redis.Redis(
    host='localhost',
    port=6379,
    charset="utf-8",
    decode_responses=True,
    db = 3
)

# %% [markdown]
# ### Load Redis Data from DB 2

# %%
dates = r.keys()
vals = r.mget(dates)

# %% [markdown]
# ### Form Basic Dfs

# %%
valsJson = [el[1:] for el in [json.loads(e) for e in vals]]

columns = ['rank','previous','title','distributor','weekGross','pctLastWeek','numberOfTheaters','numberOfTheatersChange','perTheaterAvg','totalGross','weeksInRelease']

allWeeks = []
for i, week in enumerate(tqdm(valsJson)):
    for movie in week:
        if all([v== '' for v in movie]) | (movie[0] == ''):
            continue

        movieDict = dict(zip(columns, movie))
        movieDict['date'] = dates[i]
        allWeeks.append(movieDict)
# Out:
# 100%|██████████| 2330/2330 [00:00<00:00, 13838.82it/s]

# %%
df = pd.DataFrame.from_dict(allWeeks)

df['dateDt'] = pd.to_datetime(df['date'])


for col in ['weekGross','pctLastWeek','numberOfTheaters','perTheaterAvg','totalGross']:
    df[col] = df[col].str.replace('$','', regex=False)\
                                    .str.replace(',','',regex=False)\
                                    .str.replace('%','',regex=False)\
                                    .str.replace('<','',regex=False)\
                                    .str.replace('(v)', '', regex=False)\
                                    .replace('-', np.nan)\
                                    .replace('', np.nan)\
                                    .replace('n/c', np.nan)\
                                    .astype(float)

# %%
# Rank seems to be unreliable, we'll just compute based on weekGross
df.sort_values(by=['dateDt', 'weekGross'], ascending=[False, False], inplace=True)

df['rank'] = df.groupby('date').cumcount() + 1

# %% [markdown]
# ### We now need to map title to imdbId
# - To do this, we can probably use a combination of release date and triplet title search

# %%
tmdbDf = pd.read_csv('../data/tmdbDetails.csv')
# Out:
# /var/folders/zz/znvh8gg96055nsx1ptsrmmvc0000gn/T/ipykernel_85331/2268281911.py:1: DtypeWarning: Columns (1,24,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdbDf = pd.read_csv('../data/tmdbDetails.csv')

# %%
relDf = tmdbDf[['title', 'release_date','imdb_id']]
relDf.drop_duplicates(subset='imdb_id', keep='last', inplace=True)
relDf.set_index('imdb_id', inplace=True)
candidateDict = relDf.to_dict('index')
# Out:
# /var/folders/zz/znvh8gg96055nsx1ptsrmmvc0000gn/T/ipykernel_85331/311959008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relDf.drop_duplicates(subset='imdb_id', keep='last', inplace=True)

# %%
async def tripletSearchWithYear(targetList: list, candidates: dict) -> str:
    """ Triplet search
    
        - Uses a chunk based search algorithm to search for a target against a list of candidates
        - This includes a year for final filtering
    """
    results = []
    for target in tqdm(targetList):
        scores = {}
        
        def getChunks(str, chunkSize=3):
            chunks = [] 
            for i in range(len(str)):
                chunk = str[i:i+chunkSize]
                if len(chunk)==chunkSize:
                    chunks.append(chunk)
            
            return chunks

        targetChunks = getChunks(target['title'].lower())

        for imdbId, candidate in candidates.items():
            candidateChunks = getChunks(candidate['title'].lower())
            
            intersection1 = [chunk for chunk in candidateChunks if chunk in targetChunks]
            intersection2 = [chunk for chunk in targetChunks if chunk in candidateChunks]
            
            if ((len(intersection1) > 0) & (len(intersection2))):
                intersectionScore = (len(intersection1) / len(candidateChunks)) + (len(intersection2) / len(targetChunks))
            else:
                intersectionScore = 0

            if intersectionScore > 1: # Max score is 2
                scores[imdbId] = intersectionScore

        targetRelease = arrow.get(target['dateDt'])
        targetId = target['uuid']

        maxSim = max(scores.values())
        
        maxIds = [i for i in scores.keys() if scores[i] == maxSim]
        
        if len(maxIds) == 1:
            bestMatch = maxIds[0]
        
        elif len(maxIds) > 1: # This is for disambiguation of similar titles
            deltas = {i: abs((targetRelease - arrow.get(candidates[i]['release_date'])).total_seconds()) for i in maxIds if candidates[i]['release_date'] == candidates[i]['release_date']}
            minDelta = min(deltas, key = deltas.get)
            
            bestMatch = minDelta
        else:
            bestMatch = 'NO CANDIDATE WAS FOUND'
        
        results.append({targetId: bestMatch})

    return  results

# %%
from uuid import uuid1
df['uuid'] = df.apply(lambda x: str(uuid1()), axis=1)
targetDict = df[['uuid','title','dateDt']].to_dict('records')

# %%
def tripletSearchWithYear(target, j) -> str:
    """ Triplet search
    
        - Uses a chunk based search algorithm to search for a target against a list of candidates
        - This includes a year for final filtering
    """

    scores = {}
    
    def getChunks(str, chunkSize=3):
        chunks = [] 
        for i in range(len(str)):
            chunk = str[i:i+chunkSize]
            if len(chunk)==chunkSize:
                chunks.append(chunk)
        
        return chunks

    targetChunks = getChunks(target['title'].lower())

    for imdbId, candidate in candidateDict.items():
        candidateChunks = getChunks(candidate['title'].lower())
        
        intersection1 = [chunk for chunk in candidateChunks if chunk in targetChunks]
        intersection2 = [chunk for chunk in targetChunks if chunk in candidateChunks]
        
        if ((len(intersection1) > 0) & (len(intersection2))):
            intersectionScore = (len(intersection1) / len(candidateChunks)) + (len(intersection2) / len(targetChunks))
        else:
            intersectionScore = 0

        if intersectionScore > 1: # Max score is 2
            scores[imdbId] = intersectionScore

    targetRelease = arrow.get(target['dateDt'])
    targetId = target['uuid']

    maxSim = max(scores.values())
    
    maxIds = [i for i in scores.keys() if scores[i] == maxSim]
    
    if len(maxIds) == 1:
        bestMatch = maxIds[0]
    
    elif len(maxIds) > 1: # This is for disambiguation of similar titles
        deltas = {i: abs((targetRelease - arrow.get(candidateDict[i]['release_date'])).total_seconds()) for i in maxIds if candidateDict[i]['release_date'] == candidateDict[i]['release_date']}
        minDelta = min(deltas, key = deltas.get)
        
        bestMatch = minDelta
    else:
        bestMatch = 'NO CANDIDATE WAS FOUND'

    print(f'we dun found oneeeee yeeeaassss: {j}/{len(targetDict)}')
    return  {targetId: bestMatch}

# %%
import concurrent.futures as cf
from time import time


t1 = time()
with cf.ThreadPoolExecutor() as executor:
    futures = [executor.submit(tripletSearchWithYear, target, j) for j, target in enumerate(targetDict[:100])]
    results = [future.result() for future in cf.as_completed(futures)]
    
t2 = time()

print(t2 - t1)
# Out:
# we dun found oneeeee yeeeaassss: 0.0001395543564218263
# we dun found oneeeee yeeeaassss: 0.00015284524750961928
# we dun found oneeeee yeeeaassss: 7.974534652675788e-05
# we dun found oneeeee yeeeaassss: 0.00010632712870234385
# we dun found oneeeee yeeeaassss: 0.00011961801979013683
# we dun found oneeeee yeeeaassss: 0.0001329089108779298
# we dun found oneeeee yeeeaassss: 0.00016613613859741227
# we dun found oneeeee yeeeaassss: 0/150479
# we dun found oneeeee yeeeaassss: 6/150479
# we dun found oneeeee yeeeaassss: 3/150479
# we dun found oneeeee yeeeaassss: 11/150479
# we dun found oneeeee yeeeaassss: 1/150479
# we dun found oneeeee yeeeaassss: 0.0001461998019657228
# we dun found oneeeee yeeeaassss: 9.303623761455087e-05
# we dun found oneeeee yeeeaassss: 4/150479
# we dun found oneeeee yeeeaassss: 0.00017942702968520524
# we dun found oneeeee yeeeaassss: 0.00015949069305351576
# we dun found oneeeee yeeeaassss: 5/150479
# we dun found oneeeee yeeeaassss: 0.0002060088118607912
# we dun found oneeeee yeeeaassss: 7/150479
# we dun found oneeeee yeeeaassss: 2/150479
# we dun found oneeeee yeeeaassss: 0.00017278158414130875
# we dun found oneeeee yeeeaassss: 9/150479
# we dun found oneeeee yeeeaassss: 10/150479
# we dun found oneeeee yeeeaassss: 13/150479
# we dun found oneeeee yeeeaassss: 0.0002192997029485842
# we dun found oneeeee yeeeaassss: 0.00011297257424624034
# we dun found oneeeee yeeeaassss: 15/150479
# we dun found oneeeee yeeeaassss: 0.00023923603958027367
# we dun found oneeeee yeeeaassss: 0.00018607247522910175
# we dun found oneeeee yeeeaassss: 0.00019936336631689471
# we dun found oneeeee yeeeaassss: 19/150479
# we dun found oneeeee yeeeaassss: 0.00023259059403637716
# we dun found oneeeee yeeeaassss: 0.00019271792077299823
# we dun found oneeeee yeeeaassss: 21/150479
# we dun found oneeeee yeeeaassss: 23/150479
# we dun found oneeeee yeeeaassss: 0.00024588148512417015
# we dun found oneeeee yeeeaassss: 12/150479
# we dun found oneeeee yeeeaassss: 16/150479
# we dun found oneeeee yeeeaassss: 0.0002591723762119631
# we dun found oneeeee yeeeaassss: 0.00022594514849248067
# we dun found oneeeee yeeeaassss: 0.00025252693066806663
# we dun found oneeeee yeeeaassss: 20/150479
# we dun found oneeeee yeeeaassss: 18/150479
# we dun found oneeeee yeeeaassss: 25/150479
# we dun found oneeeee yeeeaassss: 14/150479
# we dun found oneeeee yeeeaassss: 0.0002791087128436526
# we dun found oneeeee yeeeaassss: 22/150479
# we dun found oneeeee yeeeaassss: 0.00027246326729975614
# we dun found oneeeee yeeeaassss: 27/150479
# we dun found oneeeee yeeeaassss: 0.00031233594056313504
# we dun found oneeeee yeeeaassss: 0.0002923996039314456
# we dun found oneeeee yeeeaassss: 0.0002658178217558596
# we dun found oneeeee yeeeaassss: 0.0002126542574046877
# we dun found oneeeee yeeeaassss: 0.0003189813861070315
# we dun found oneeeee yeeeaassss: 0.00030569049501923855we dun found oneeeee yeeeaassss: 24/150479
# we dun found oneeeee yeeeaassss: 0.00032562683165092806
# we dun found oneeeee yeeeaassss: 0.00029904504947534207
# we dun found oneeeee yeeeaassss: 17/150479
# we dun found oneeeee yeeeaassss: 0.00033227227719482454
# we dun found oneeeee yeeeaassss: 26/150479
# we dun found oneeeee yeeeaassss: 31/150479
# we dun found oneeeee yeeeaassss: 0.0002857541583875491
# we dun found oneeeee yeeeaassss: 36/150479
# we dun found oneeeee yeeeaassss: 33/150479
# we dun found oneeeee yeeeaassss: 28/150479
# we dun found oneeeee yeeeaassss: 29/150479
# we dun found oneeeee yeeeaassss: 30/150479
# we dun found oneeeee yeeeaassss: 35/150479
# we dun found oneeeee yeeeaassss: 34/150479
# we dun found oneeeee yeeeaassss: 0.0003721449504582035
# we dun found oneeeee yeeeaassss: 0.00039872673263378943
# we dun found oneeeee yeeeaassss: 0.000338917722738721
# we dun found oneeeee yeeeaassss: 0.0003455631682826175
# we dun found oneeeee yeeeaassss: 0.0004120176237215824
# we dun found oneeeee yeeeaassss: 37/150479
# we dun found oneeeee yeeeaassss: 0.0004053721781776859
# we dun found oneeeee yeeeaassss: 39/150479
# we dun found oneeeee yeeeaassss: 0.00038543584154599646we dun found oneeeee yeeeaassss: 0.0003588540593704105
# we dun found oneeeee yeeeaassss: 38/150479
# we dun found oneeeee yeeeaassss: 0.0003787903960021
# we dun found oneeeee yeeeaassss: 0.00036549950491430696
# we dun found oneeeee yeeeaassss: 0.00044524485144106486
# we dun found oneeeee yeeeaassss: 41/150479
# we dun found oneeeee yeeeaassss: 0.0004253085148093754
# we dun found oneeeee yeeeaassss: 42/150479
# we dun found oneeeee yeeeaassss: 40/150479
# we dun found oneeeee yeeeaassss: 47/150479
# we dun found oneeeee yeeeaassss: 48/150479
# we dun found oneeeee yeeeaassss: 46/150479
# we dun found oneeeee yeeeaassss: 44/150479we dun found oneeeee yeeeaassss: 0.00047182663361665085
#
# we dun found oneeeee yeeeaassss: 49/150479
# we dun found oneeeee yeeeaassss: 32/150479we dun found oneeeee yeeeaassss: 45/150479
#
# we dun found oneeeee yeeeaassss: 43/150479
# we dun found oneeeee yeeeaassss: 50/150479
# we dun found oneeeee yeeeaassss: 0.00039208128708989294
# we dun found oneeeee yeeeaassss: 0.00045189029698496135
# we dun found oneeeee yeeeaassss: 0.0004385994058971684
# we dun found oneeeee yeeeaassss: 0.0004851175247044438
# we dun found oneeeee yeeeaassss: 0.0004984084157922368
# we dun found oneeeee yeeeaassss: 0.0004319539603532719
# we dun found oneeeee yeeeaassss: 0.0004651811880727543
# we dun found oneeeee yeeeaassss: 0.0004917629702483403
# we dun found oneeeee yeeeaassss: 0.0004186630692654789
# we dun found oneeeee yeeeaassss: 56/150479
# we dun found oneeeee yeeeaassss: 62/150479
# we dun found oneeeee yeeeaassss: 0.00045853574252885783
# we dun found oneeeee yeeeaassss: 60/150479
# we dun found oneeeee yeeeaassss: 61/150479we dun found oneeeee yeeeaassss: 0.00047847207916054733
#
# we dun found oneeeee yeeeaassss: 52/150479
# we dun found oneeeee yeeeaassss: 58/150479
# we dun found oneeeee yeeeaassss: 51/150479
# we dun found oneeeee yeeeaassss: 0.0005116993068800298
# we dun found oneeeee yeeeaassss: 0.0005449265345995123
# we dun found oneeeee yeeeaassss: 54/150479
# we dun found oneeeee yeeeaassss: 0.0005050538613361333
# we dun found oneeeee yeeeaassss: 55/150479
# we dun found oneeeee yeeeaassss: 0.0005183447524239262
# we dun found oneeeee yeeeaassss: 64/150479
# we dun found oneeeee yeeeaassss: 57/150479
# we dun found oneeeee yeeeaassss: 0.0005648628712312017
# we dun found oneeeee yeeeaassss: 0.0005515719801434088we dun found oneeeee yeeeaassss: 67/150479
# we dun found oneeeee yeeeaassss: 0.0005249901979678227
# we dun found oneeeee yeeeaassss: 71/150479
# we dun found oneeeee yeeeaassss: 0.0005582174256873052
# we dun found oneeeee yeeeaassss: 0.0005382810890556157
# we dun found oneeeee yeeeaassss: 59/150479
# we dun found oneeeee yeeeaassss: 0.0005781537623189947
# we dun found oneeeee yeeeaassss: 0.0005847992078628912
# we dun found oneeeee yeeeaassss: 68/150479
# we dun found oneeeee yeeeaassss: 65/150479
# we dun found oneeeee yeeeaassss: 66/150479
# we dun found oneeeee yeeeaassss: 74/150479
# we dun found oneeeee yeeeaassss: 73/150479
# we dun found oneeeee yeeeaassss: 0.0006047355444945806
# we dun found oneeeee yeeeaassss: 63/150479
# we dun found oneeeee yeeeaassss: 0.0005914446534067877
# we dun found oneeeee yeeeaassss: 0.0005980900989506841
# we dun found oneeeee yeeeaassss: 75/150479
# we dun found oneeeee yeeeaassss: 70/150479
# we dun found oneeeee yeeeaassss: 69/150479
# we dun found oneeeee yeeeaassss: 0.0006113809900384771
# we dun found oneeeee yeeeaassss: 0.0006180264355823736
# we dun found oneeeee yeeeaassss: 0.0006246718811262701
# we dun found oneeeee yeeeaassss: 77/150479
# we dun found oneeeee yeeeaassss: 72/150479
# we dun found oneeeee yeeeaassss: 0.0006512536633018561
# we dun found oneeeee yeeeaassss: 82/150479
# we dun found oneeeee yeeeaassss: 76/150479
# we dun found oneeeee yeeeaassss: 0.0006578991088457526
# we dun found oneeeee yeeeaassss: 0.0006313173266701666
# we dun found oneeeee yeeeaassss: 0.0006446082177579596
# we dun found oneeeee yeeeaassss: 0.0005316356435117192
# we dun found oneeeee yeeeaassss: 85/150479
# we dun found oneeeee yeeeaassss: 78/150479
# we dun found oneeeee yeeeaassss: 0.0005715083167750982
# we dun found oneeeee yeeeaassss: 79/150479
# we dun found oneeeee yeeeaassss: 83/150479
# we dun found oneeeee yeeeaassss: 0.000637962772214063
# we dun found oneeeee yeeeaassss: 84/150479
# we dun found oneeeee yeeeaassss: 81/150479
# we dun found oneeeee yeeeaassss: 88/150479
# we dun found oneeeee yeeeaassss: 87/150479
# we dun found oneeeee yeeeaassss: 89/150479
# we dun found oneeeee yeeeaassss: 90/150479
# we dun found oneeeee yeeeaassss: 91/150479
# we dun found oneeeee yeeeaassss: 92/150479
# we dun found oneeeee yeeeaassss: 93/150479
# we dun found oneeeee yeeeaassss: 94/150479
# we dun found oneeeee yeeeaassss: 98/150479
# we dun found oneeeee yeeeaassss: 80/150479
# we dun found oneeeee yeeeaassss: 95/150479
# we dun found oneeeee yeeeaassss: 86/150479
# we dun found oneeeee yeeeaassss: 99/150479
# we dun found oneeeee yeeeaassss: 97/150479
# we dun found oneeeee yeeeaassss: 96/150479
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       6 with cf.ThreadPoolExecutor() as executor:
#       7     futures = [executor.submit(tripletSearchWithYear, target, j) for j, target in enumerate(targetDict[:100])]
# ----> 8     results = [future.result() for future in cf.as_completed(futures)]
#       9 t2 = time()
#      11 print(t2 - t1)
#
# File /opt/miniconda3/envs/mid/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/miniconda3/envs/mid/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/miniconda3/envs/mid/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[12], line 38, in tripletSearchWithYear(target, j)
#      35 targetRelease = arrow.get(target['dateDt'])
#      36 targetId = target['uuid']
# ---> 38 maxSim = max(scores.values())
#      40 maxIds = [i for i in scores.keys() if scores[i] == maxSim]
#      42 if len(maxIds) == 1:
#
# ValueError: max() iterable argument is empty

# %% [markdown]
# ### Save to CSV

# %%
mergedDf.to_csv('../data/allBoxOffice.csv')
